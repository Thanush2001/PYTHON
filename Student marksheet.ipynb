# %% [markdown]
# # STUDENT MARKSHEET

# %%
class parent:
    def get1(self):
        print("10th candidate marksheeet")
        print("TMKV govt boys hr sec school")
        self.name=input("enter the name=")
        self.dob=input("enter the dob=")
class child1(parent):
    def get2(self):
        self.rollno=1803666
        self.tamil=58
        self.english=62
        self.maths=57
        self.science=81
        self.socialscience=70
    def calc(self):    
        self.total=self.tamil+self.english+self.maths+self.science+self.socialscience
        self.avg=self.total//5
    def show(self):
        if(self.tamil>=35 and self.english>=35 and self.maths>=35 and self.science>=35 and self.socialscience>=35):
            print("Name=",self.name)
            print("dob=",self.dob)
            print("Tamil=",self.tamil)
            print("English=",self.english)
            print("Maths=",self.maths)
            print("Science=",self.science)
            print("SocialScience=",self.socialscience)
            print("Total=",self.total)
            print("Average=",self.avg)
            print("Pass")
            if(self.avg>=90 and self.avg<100):
                print("A Grade","\n")
            elif(self.avg>=70 and self.avg<90):
                print("B Grade","\n")
            elif(self.avg>=50 and self.avg<70):
                print("C Grade","\n")
            else:
                print("D Grade","\n")
        else:
            print("Fail")

class child2(parent):
    def get3(self):
        print("+2 candidate marksheet")
        print("TMKV govt boys hr sec school")
        name=(input("Enter the name="))
        Rollno=1681437
        Tamil=111
        English=118
        physics=101
        chemistry=85
        computerscience=120  
        mathematics=131
        total=Tamil+English+physics+chemistry+computerscience+mathematics
        avg=total//6
        per=avg/2
        if(Tamil>=45 and English>=45 and mathematics>=45 and computerscience>=45 and chemistry>=45 and physics>=45):
            print("Tamil=",Tamil)
            print("English=",English)
            print("physics=",physics)
            print("chemistry=",chemistry)
            print("computerscience=",computerscience)
            print("mathematics=",mathematics)
            print("Total=",total)
            print("Average=",avg)
            print("percentage=",per)
            print("Pass")
            if(avg>=90 and avg<100):
                print("A Grade","\n")
            elif(avg>=70 and avg<90):
                print("B Grade","\n")
            elif(avg>=50 and avg<70):
                print("C Grade","\n")
            else:
                print("D Grade","\n")
        else:
            print("Fail")

class child3(parent):
    def sem1(self):
        print("Degree marks 2018-2022")
        print("Global institute of engineering and technology")
        print("semester 1")
        name=(input("Enter the name="))
        Regno=int(input("enter the regno="))
        chemistry=66
        python=77
        EG=67
        m1=66
        physics=55
        english=78
        total=chemistry+english+physics+python+EG+m1
        avg=total//6
        if(chemistry>=45 and python>=45 and EG>=45 and m1>=45 and physics>=45 and english>=45):
            print("chemistry=",chemistry)
            print("python=",python)
            print("EG=",EG)
            print("m1=",m1)
            print("physics=",physics)
            print("english=",english)
            print("Total=",total)
            print("Average=",avg)
            print("Pass")
            if(avg>=90 and avg<100):
                print("A Grade","\n")
            elif(avg>=70 and avg<90):
                print("B Grade","\n")
            elif(avg>=50 and avg<70):
                print("C Grade","\n")
            else:
                print("D Grade","\n")
        else:
            print("Fail")
    def sem2(sem1):
        print("semester 2")
        bei=88
        circuitanalysis=55
        electronicdevice=67
        english2=59
        m2=69
        physics2=66
        total=circuitanalysis+english2+physics2+electronicdevice+bei+m2
        avg=total//6
        if(bei>=45 and circuitanalysis>=45 and electronicdevice>=45 and m2>=45 and physics2>=45 and english2>=45):
            print("bei=",bei)
            print("circuit analysis=",circuitanalysis)
            print("electronic device=",electronicdevice)
            print("english2=",english2)
            print("m2=",m2)
            print("physics2=",physics2)
            print("Total=",total)
            print("Average=",avg)
            print("Pass")
            if(avg>=90 and avg<100):
                print("A Grade","\n")
            elif(avg>=70 and avg<90):
                print("B Grade","\n")
            elif(avg>=50 and avg<70):
                print("C Grade","\n")
            else:
                print("D Grade","\n")
        else:
            print("Fail")
    def sem3(sem2):
        print("semester 3")
        fdsc=66
        m3=77
        ec1=88
        digitalelectronics=57
        controlsystem=67
        siginalsystem=77
        total=fdsc+m3+ec1+digitalelectronics+controlsystem+siginalsystem
        avg=total//6
        if(fdsc>=45 and m3>=45 and digitalelectronics>=45 and controlsystem>=45 and ec1>=45 and siginalsystem>=45):
            print("fdsc=",fdsc)
            print("m3=",m3)
            print("digitalelectronics=",digitalelectronics)
            print("controlsystem=",controlsystem)
            print("ec1=",ec1)
            print("siginalsystem=",siginalsystem)
            print("Total=",total)
            print("Average=",avg)
            print("Pass")
            if(avg>=90 and avg<100):
                print("A Grade","\n")
            elif(avg>=70 and avg<90):
                print("B Grade","\n")
            elif(avg>=50 and avg<70):
                print("C Grade","\n")
            else:
                print("D Grade","\n")
        else:
            print("Fail")
    def sem4(sem3):
        print("semester 4")
        evs=69
        ct=70
        ec2=80
        electromagneticfield=51
        lic=60
        prp=47
        total=evs+ct+ec2+electromagneticfield+lic+prp
        avg=total//6
        if(evs>=45 and ct>=45 and electromagneticfield>=45 and ec2>=45 and lic>=45 and prp>=45):
            print("evs=",evs)
            print("ct=",ct)
            print("ec2=",ec2)
            print("electromagnetic field=",electromagneticfield)
            print("lic=",lic)
            print("prp=",prp)
            print("Total=",total)
            print("Average=",avg)
            print("Pass")
            if(avg>=90 and avg<100):
                print("A Grade","\n")
            elif(avg>=70 and avg<90):
                print("B Grade","\n")
            elif(avg>=50 and avg<70):
                print("C Grade","\n")
            else:
                print("D Grade","\n")
        else:
            print("Fail")
    def sem5(sem4):
        print("semester 5")
        me=60
        dc=56
        cn=66
        cao=48
        dsp=77
        airpollution=88
        total=me+dc+cn+cao+dsp+airpollution
        avg=total//6
        if(me>=45 and dc>=45 and cn>=45 and cao>=45 and dsp>=45 and airpollution>=45):
            print("me=",me)
            print("dc=",dc)
            print("cn=",cn)
            print("cao=",cao)
            print("dsp=",dsp)
            print("airpollution=",airpollution)
            print("Total=",total)
            print("Average=",avg)
            print("Pass")
            if(avg>=90 and avg<100):
                print("A Grade","\n")
            elif(avg>=70 and avg<90):
                print("B Grade","\n")
            elif(avg>=50 and avg<70):
                print("C Grade","\n")
            else:
                print("D Grade","\n")
        else:
            print("Fail")
    def sem6(sem5):
        print("semester 6")
        wn=60
        vlsi=60
        wc=55
        mpmc=71
        pc=50
        pom=77
        total=wn+vlsi+wc+mpmc+pc+pom
        avg=total//6
        if(wn>=45 and vlsi>=45 and wc>=45 and mpmc>=45 and pc>=45 and pom>=45):
            print("wn=",wn)
            print("vlsi=",vlsi)
            print("wc=",wc)
            print("mpmc=",mpmc)
            print("pc=",pc)
            print("pom=",pom)
            print("Total=",total)
            print("Average=",avg)
            print("Pass")
            if(avg>=90 and avg<100):
                print("A Grade","\n")
            elif(avg>=70 and avg<90):
                print("B Grade","\n")
            elif(avg>=50 and avg<70):
                print("C Grade","\n")
            else:
                print("D Grade","\n1")
        else:
            print("Fail")
    def sem7(sem6):
        print("semester 7")
        cr=60
        antenna=60
        adhoc=90
        oc=71
        embedded=50
        industrialsafety=47
        total=cr+antenna+adhoc+oc+embedded+industrialsafety
        avg=total//6
        if(cr>=45 and antenna>=45 and adhoc>=45 and oc>=45 and embedded>=45 and industrialsafety>=45):
            print("cr=",cr)
            print("antenna=",antenna)
            print("adhoc=",adhoc)
            print("oc=",oc)
            print("embeddeed=",embedded)
            print("industrial safety=",industrialsafety)
            print("Total=",total)
            print("Average=",avg)
            print("Pass")
            if(avg>=90 and avg<100):
                print("A Grade","\n")
            elif(avg>=70 and avg<90):
                print("B Grade","\n")
            elif(avg>=50 and avg<70):
                print("C Grade","\n")
            else:
                print("D Grade","\n")
        else:
            print("Fail")
    def sem8(self):
        print("semester 8")
        sc=70
        pe=69
        total=sc+pe
        avg=total//2
        if(sc>=45 and pe>=45):
            print("sc=",sc)
            print("pe=",pe)
            print("Total=",total)
            print("Average=",avg)
            print("Pass")
            if(avg>=90 and avg<100):
                print("A Grade")
            elif(avg>=70 and avg<90):
                print("B Grade")
            elif(avg>=50 and avg<70):
                print("C Grade")
            else:
                print("D Grade")
        else:
            print("Fail")
        
obj=child1()
obj.get1()
obj.get2()
obj.calc()
obj.show()
obj=child2()
obj.get3()
obj=child3()
obj.sem1()
obj.sem2()
obj.sem3()
obj.sem4()
obj.sem5()
obj.sem6()
obj.sem7()
obj.sem8()
# Out:
# 10th candidate marksheeet
# TMKV govt boys hr sec school
# enter the name=Thanush V
# enter the dob=23/03/2001
# Name= Thanush V
# dob= 23/03/2001
# Tamil= 58
# English= 62
# Maths= 57
# Science= 81
# SocialScience= 70
# Total= 328
# Average= 65
# Pass
# C Grade
#
# +2 candidate marksheet
# TMKV govt boys hr sec school
# Enter the name=Thanush V
# Tamil= 111
# English= 118
# physics= 101
# chemistry= 85
# computerscience= 120
# mathematics= 131
# Total= 666
# Average= 111
# percentage= 55.5
# Pass
# D Grade
#
# Degree marks 2018-2022
# Global institute of engineering and technology
# semester 1
# Enter the name=Thanush V
# enter the regno=510918106014
# chemistry= 66
# python= 77
# EG= 67
# m1= 66
# physics= 55
# english= 78
# Total= 409
# Average= 68
# Pass
# C Grade
#
# semester 2
# bei= 88
# circuit analysis= 55
# electronic device= 67
# english2= 59
# m2= 69
# physics2= 66
# Total= 404
# Average= 67
# Pass
# C Grade
#
# semester 3
# fdsc= 66
# m3= 77
# digitalelectronics= 57
# ...
